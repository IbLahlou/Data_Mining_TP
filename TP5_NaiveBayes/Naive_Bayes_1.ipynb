# %% [markdown]
# ## TP | Conception de Naive Bayes from Scratch
#
# ### Objectif
#
# L'objectif de ce TP est de développer un classifieur Naive Bayes à partir de zéro en utilisant Python, en se basant sur le dataset "iris.csv". L'ensemble de données contient des mesures de fleurs d'iris, et l'objectif est de classifier ces fleurs en trois classes : Iris-setosa, Iris-versicolor, Iris-virginica.
#
# ### Problèmatique
#
# - **Choix du Classifieur :** Comment choisir le type spécifique de Naive Bayes adapté au dataset "iris.csv"? Quelles sont les implications de ce choix sur la performance du modèle?
#
# - **Performance sur un Sous-ensemble :** Comment évaluer la performance du classifieur Naive Bayes sur un sous-ensemble du dataset? Quelles tendances ou observations sont importantes dans les probabilités calculées et les classifications?
#
# - **Évaluation Globale de la Performance :** Comment diviser le dataset en ensembles d'entraînement et de test de manière appropriée? Quelle est l'accuracy du modèle Naive Bayes sur l'ensemble de test, et comment interpréter ces résultats?
#
# - **Comparaison avec un Modèle Profond :** Comment concevoir et entraîner un réseau de neurones profond avec une seule couche cachée pour la classification du dataset "iris.csv"? Quelle est la comparaison de la performance entre Naive Bayes et le modèle de réseau de neurones profond?

# %%
# Execute this just once or restart the kernel to avoid errors
import os 

os.chdir("../data")
# %pwd
# Out:
# 'c:\\Users\\P52s\\Documents\\Obsidian\\Semestre 1 IDSCC5\\5eme année\\Data mining\\TPs\\data'

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import random
from pprint import pprint

# %matplotlib inline
sns.set_style("darkgrid")


print("Set up Complete !")
# Out:
# Set up Complete !

# %%
df=pd.read_csv("iris.data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   5.1          149 non-null    float64
#  1   3.5          149 non-null    float64
#  2   1.4          149 non-null    float64
#  3   0.2          149 non-null    float64
#  4   Iris-setosa  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df.plot()
# Out:
# <AxesSubplot:>
